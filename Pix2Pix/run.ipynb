# %%
# !python3 '/content/drive/MyDrive/code_example/pix2pix/main.py' \
         --mode 'train' \
         --train_continue 'on' \
         --norm 'bnorm' \
         --opts 'direction' 0 \
         --num_epoch 50 \
         --data_dir '/content/drive/MyDrive/code_example/pix2pix/facades/facades' \
         --ckpt_dir '/content/drive/MyDrive/code_example/pix2pix/checkpoint_a2b_bnorm' \
         --log_dir '/content/drive/MyDrive/code_example/pix2pix/log_a2b_bnorm' \
         --result_dir '/content/drive/MyDrive/code_example/pix2pix/result_a2b_bnorm'
# Out:
# 2024-10-15 12:06:55.988775: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-15 12:06:56.009589: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-15 12:06:56.015823: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-15 12:06:56.031113: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python3 '/content/drive/MyDrive/code_example/pix2pix/main.py' \
         --mode 'test' \
         --train_continue 'on' \
         --norm 'bnorm' \
         --opts 'direction' 0 \
         --data_dir '/content/drive/MyDrive/code_example/pix2pix/facades/facades' \
         --ckpt_dir '/content/drive/MyDrive/code_example/pix2pix/checkpoint_a2b_bnorm' \
         --log_dir '/content/drive/MyDrive/code_example/pix2pix/log_a2b_bnorm' \
         --result_dir '/content/drive/MyDrive/code_example/pix2pix/result_a2b_bnorm'
# Out:
# 2024-10-15 11:39:55.345610: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-15 11:39:55.380514: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-15 11:39:55.387408: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-15 11:39:55.407580: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
