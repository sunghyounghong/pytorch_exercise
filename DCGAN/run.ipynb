# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !python "/content/drive/MyDrive/code_example/DCGAN/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/code_example/u-net-image-regression/BSDS500/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/code_example/DCGAN/checkpoint/" \
--log_dir "/content/drive/MyDrive/code_example/DCGAN/log/" \
--result_dir "/content/drive/MyDrive/code_example/DCGAN/result/" \
--network "DCGAN" \
--num_epoch 200 \
--batch_size 128
# Out:
# 2024-10-14 06:41:06.658647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-14 06:41:06.678385: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-14 06:41:06.684794: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-14 06:41:06.698691: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python "/content/drive/MyDrive/code_example/DCGAN/train.py" \
--mode "test" \
--data_dir "/content/drive/MyDrive/code_example/u-net-image-regression/BSDS500/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/code_example/DCGAN/checkpoint/" \
--log_dir "/content/drive/MyDrive/code_example/DCGAN/log/" \
--result_dir "/content/drive/MyDrive/code_example/DCGAN/result/" \
--network "DCGAN" \
--batch_size 128
# Out:
# 2024-10-14 06:55:50.384616: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-14 06:55:50.416873: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-14 06:55:50.426728: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-14 06:55:50.448533: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
