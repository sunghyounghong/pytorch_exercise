# %%
# !python3 /content/drive/MyDrive/code_example/cyclegan/main.py \
        --mode 'train' \
        --train_continue 'on' \
        --lr 2e-4 \
        --batch_size 4 \
        --num_epoch 100 \
        --ny 256 \
        --nx 256 \
        --nch 3 \
        --nker 64 \
        --wgt_cycle 1e2 \
        --wgt_ident 5e-1 \
        --network 'CycleGAN' \
        --data_dir '/content/drive/MyDrive/code_example/cyclegan/monet2photo' \
        --ckpt_dir '/content/drive/MyDrive/code_example/cyclegan/checkpoint' \
        --log_dir '/content/drive/MyDrive/code_example/cyclegan/log' \
        --result_dir '/content/drive/MyDrive/code_example/cyclegan/result'
# Out:
# 2024-10-16 05:04:05.021733: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-16 05:04:05.088296: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-16 05:04:05.107670: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-16 05:04:05.269302: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
