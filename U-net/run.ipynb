# %%
# %load_ext tensorboard

# %%
tensorboard --logdir='./drive/My Drive/training_unet/log'

# %%
# !python3 "/content/drive/MyDrive/code_example/u-net/train.py" \
--lr 1e-3 --batch_size 2 --num_epoch 100 \
--data_dir "/content/drive/MyDrive/code_example/u-net/" \
--ckpt_dir "/content/drive/MyDrive/code_example/u-net/checkpoint_v2" \
--log_dir "/content/drive/MyDrive/code_example/u-net/log_v2" \
--result_dir "/content/drive/MyDrive/code_example/u-net/result_v2" \
--mode "test" \
--train_continue "off"
