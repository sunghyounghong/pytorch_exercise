# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
# ...

# %%
# !python /content/drive/MyDrive/code_example/u-net-image-regression/train.py \
--mode 'train' \
--data_dir /content/drive/MyDrive/code_example/u-net-image-regression/BSDS500/BSDS500/data/images \
--ckpt_dir /content/drive/MyDrive/code_example/u-net-image-regression/checkpoint/inpainting/plain \
--log_dir /content/drive/MyDrive/code_example/u-net-image-regression/log/inpainting/plain \
--result_dir /content/drive/MyDrive/code_example/u-net-image-regression/result/inpainting/plain \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/code_example/u-net-image-regression/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/code_example/u-net-image-regression/BSDS500/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/code_example/u-net-image-regression/checkpoint/denoising/plain" \
--log_dir "/content/drive/MyDrive/code_example/u-net-image-regression/log/denoising/plain" \
--result_dir "/content/drive/MyDrive/code_example/u-net-image-regression/result/denoising/plain" \
--network "unet" \
--batch_size 2 \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "plain"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Valid: Epoch 0067 / 0100 | Batch 0001 / 0050 | Loss 0.0106
# Valid: Epoch 0067 / 0100 | Batch 0002 / 0050 | Loss 0.0089
# Valid: Epoch 0067 / 0100 | Batch 0003 / 0050 | Loss 0.0088
# Valid: Epoch 0067 / 0100 | Batch 0004 / 0050 | Loss 0.0092
# Valid: Epoch 0067 / 0100 | Batch 0005 / 0050 | Loss 0.0088
# Valid: Epoch 0067 / 0100 | Batch 0006 / 0050 | Loss 0.0090
# Valid: Epoch 0067 / 0100 | Batch 0007 / 0050 | Loss 0.0086
# Valid: Epoch 0067 / 0100 | Batch 0008 / 0050 | Loss 0.0087
# Valid: Epoch 0067 / 0100 | Batch 0009 / 0050 | Loss 0.0085
# Valid: Epoch 0067 / 0100 | Batch 0010 / 0050 | Loss 0.0090
# Valid: Epoch 0067 / 0100 | Batch 0011 / 0050 | Loss 0.0095
# Valid: Epoch 0067 / 0100 | Batch 0012 / 0050 | Loss 0.0095
# Valid: Epoch 0067 / 0100 | Batch 0013 / 0050 | Loss 0.0096
# Valid: Epoch 0067 / 0100 | Batch 0014 / 0050 | Loss 0.0095
# Valid: Epoch 0067 / 0100 | Batch 0015 / 0050 | Loss 0.0098
# ...
